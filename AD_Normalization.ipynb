# %%
import pandas as pd
data = pd.read_csv('data.csv')

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
data['class'] = data['class'].map({'P':1, 'H':0})

# %%
X = data.drop(columns=['ID','class'], axis=1)

# %%
y = data['class']

# %%
X_df= X

# %%
X = X.to_numpy()

# %%
minmax = MinMaxScaler()
x1 = minmax.fit_transform(X)


standard = StandardScaler()
x2 = standard.fit_transform(X)


robust = RobustScaler()
x3 = robust.fit_transform(X)

# %%
minmaxdf= pd.DataFrame(x1, columns=X_df.columns)
minmaxdf.head()
# Out:
#    air_time1  disp_index1  gmrt_in_air1  gmrt_on_paper1  max_x_extension1  \
# 0   0.046360     0.406461      0.080792        0.068142          0.011374
# 1   0.472384     0.537941      0.075978        0.064066          0.052667
# 2   0.023066     0.323817      0.176554        0.170993          0.088469
# 3   0.018790     0.323817      0.298939        0.183481          0.056141
# 4   0.020428     0.194591      0.201179        0.097381          0.013055
#
#    max_y_extension1  mean_acc_in_air1  mean_acc_on_paper1  mean_gmrt1  \
# 0          0.396794          0.108714            0.227669    0.078721
# 1          0.422875          0.075704            0.090912    0.073134
# 2          0.344304          0.118038            0.159616    0.201296
# 3          0.499146          0.180837            0.127886    0.295504
# 4          0.274011          0.073324            0.091335    0.180291
#
#    mean_jerk_in_air1  ...  mean_gmrt25  mean_jerk_in_air25  \
# ...

# %%
standarddf= pd.DataFrame(x2, columns=X_df.columns)
standarddf.head()
# Out:
#    air_time1  disp_index1  gmrt_in_air1  gmrt_on_paper1  max_x_extension1  \
# 0  -0.039958     0.819201     -0.964281       -1.021048         -0.621190
# 1   3.670803     1.863195     -0.994191       -1.051635         -0.172774
# 2  -0.242853     0.162976     -0.369289       -0.249241          0.216015
# 3  -0.280104     0.162976      0.391119       -0.155526         -0.135051
# 4  -0.265837    -0.863121     -0.216284       -0.801634         -0.602937
#
#    max_y_extension1  mean_acc_in_air1  mean_acc_on_paper1  mean_gmrt1  \
# 0         -0.331301         -0.143336            0.583446   -1.097797
# 1         -0.149357         -0.377846           -0.541698   -1.131393
# 2         -0.697480         -0.077097            0.023550   -0.360783
# 3          0.382725          0.369034           -0.237507    0.205663
# 4         -1.187857         -0.394751           -0.538220   -0.487082
#
#    mean_jerk_in_air1  ...  mean_gmrt25  mean_jerk_in_air25  \
# ...

# %%
robustdf= pd.DataFrame(x3, columns=X_df.columns)
robustdf.head()
# Out:
#    air_time1  disp_index1  gmrt_in_air1  gmrt_on_paper1  max_x_extension1  \
# 0   0.701971     0.837525     -0.730590       -0.919134         -1.005207
# 1  15.180518     1.789259     -0.760281       -0.954044          0.018049
# 2  -0.089679     0.239293     -0.139948       -0.038273          0.905241
# 3  -0.235021     0.239293      0.614900        0.068684          0.104131
# 4  -0.179358    -0.696125      0.011938       -0.668718         -0.963554
#
#    max_y_extension1  mean_acc_in_air1  mean_acc_on_paper1  mean_gmrt1  \
# 0         -0.172223          0.385823            1.273950   -0.905148
# 1          0.010347         -0.011898           -0.444669   -0.938507
# 2         -0.539664          0.498162            0.418729   -0.173330
# 3          0.544263          1.254786            0.019972    0.389123
# 4         -1.031731         -0.040569           -0.439356   -0.298739
#
#    mean_jerk_in_air1  ...  mean_gmrt25  mean_jerk_in_air25  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X_df.columns
# Out:
# Index(['air_time1', 'disp_index1', 'gmrt_in_air1', 'gmrt_on_paper1',
#        'max_x_extension1', 'max_y_extension1', 'mean_acc_in_air1',
#        'mean_acc_on_paper1', 'mean_gmrt1', 'mean_jerk_in_air1',
#        ...
#        'mean_gmrt25', 'mean_jerk_in_air25', 'mean_jerk_on_paper25',
#        'mean_speed_in_air25', 'mean_speed_on_paper25', 'num_of_pendown25',
#        'paper_time25', 'pressure_mean25', 'pressure_var25', 'total_time25'],
#       dtype='object', length=450)

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols = 4, figsize =(20, 5))
ax1.set_title('Before Scaling')

sns.kdeplot(X_df['air_time1'], ax = ax1, color ='r')
sns.kdeplot(X_df['disp_index1'], ax = ax1, color ='b')
ax2.set_title('After Robust Scaling')


sns.kdeplot(robustdf['air_time1'], ax = ax2, color ='red')
sns.kdeplot(robustdf['disp_index1'], ax = ax2, color ='blue')
ax3.set_title('After Standard Scaling')

sns.kdeplot(standarddf['air_time1'], ax = ax3, color ='black')
sns.kdeplot(standarddf['disp_index1'], ax = ax3, color ='g')
ax4.set_title('After Min-Max Scaling')

sns.kdeplot(minmaxdf['air_time1'], ax = ax4, color ='black')
sns.kdeplot(minmaxdf['disp_index1'], ax = ax4, color ='g')
plt.show()
plt.savefig('n1.jpeg')

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols = 4, figsize =(20, 5))
ax1.set_title('Before Scaling')

sns.kdeplot(X_df['gmrt_in_air1'], ax = ax1, color ='r')
sns.kdeplot(X_df['gmrt_on_paper1'], ax = ax1, color ='b')
ax2.set_title('After Robust Scaling')


sns.kdeplot(robustdf['gmrt_in_air1'], ax = ax2, color ='red')
sns.kdeplot(robustdf['gmrt_on_paper1'], ax = ax2, color ='blue')
ax3.set_title('After Standard Scaling')

sns.kdeplot(standarddf['gmrt_in_air1'], ax = ax3, color ='black')
sns.kdeplot(standarddf['gmrt_on_paper1'], ax = ax3, color ='g')
ax4.set_title('After Min-Max Scaling')

sns.kdeplot(minmaxdf['gmrt_in_air1'], ax = ax4, color ='black')
sns.kdeplot(minmaxdf['gmrt_on_paper1'], ax = ax4, color ='g')
plt.show()
plt.savefig('n2.jpeg')

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols = 4, figsize =(20, 5))
ax1.set_title('Before Scaling')

sns.kdeplot(X_df['max_x_extension1'], ax = ax1, color ='r')
sns.kdeplot(X_df['max_y_extension1'], ax = ax1, color ='b')
ax2.set_title('After Robust Scaling')


sns.kdeplot(robustdf['max_x_extension1'], ax = ax2, color ='red')
sns.kdeplot(robustdf['max_y_extension1'], ax = ax2, color ='blue')
ax3.set_title('After Standard Scaling')

sns.kdeplot(standarddf['max_x_extension1'], ax = ax3, color ='black')
sns.kdeplot(standarddf['max_y_extension1'], ax = ax3, color ='g')
ax4.set_title('After Min-Max Scaling')

sns.kdeplot(minmaxdf['max_x_extension1'], ax = ax4, color ='black')
sns.kdeplot(minmaxdf['max_y_extension1'], ax = ax4, color ='g')
plt.show()
plt.savefig('n3.jpeg')

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols = 4, figsize =(20, 5))
ax1.set_title('Before Scaling')

sns.kdeplot(X_df['mean_acc_in_air1'], ax = ax1, color ='r')
sns.kdeplot(X_df['mean_acc_on_paper1'], ax = ax1, color ='b')
ax2.set_title('After Robust Scaling')


sns.kdeplot(robustdf['mean_acc_in_air1'], ax = ax2, color ='red')
sns.kdeplot(robustdf['mean_acc_on_paper1'], ax = ax2, color ='blue')
ax3.set_title('After Standard Scaling')

sns.kdeplot(standarddf['mean_acc_in_air1'], ax = ax3, color ='black')
sns.kdeplot(standarddf['mean_acc_on_paper1'], ax = ax3, color ='g')
ax4.set_title('After Min-Max Scaling')

sns.kdeplot(minmaxdf['mean_acc_in_air1'], ax = ax4, color ='black')
sns.kdeplot(minmaxdf['mean_acc_on_paper1'], ax = ax4, color ='g')
plt.show()
plt.savefig('n4.jpeg')

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols = 4, figsize =(20, 5))
ax1.set_title('Before Scaling')

sns.kdeplot(X_df['mean_gmrt1'], ax = ax1, color ='r')
sns.kdeplot(X_df['mean_jerk_in_air1'], ax = ax1, color ='b')
ax2.set_title('After Robust Scaling')


sns.kdeplot(robustdf['mean_gmrt1'], ax = ax2, color ='red')
sns.kdeplot(robustdf['mean_jerk_in_air1'], ax = ax2, color ='blue')
ax3.set_title('After Standard Scaling')

sns.kdeplot(standarddf['mean_gmrt1'], ax = ax3, color ='black')
sns.kdeplot(standarddf['mean_jerk_in_air1'], ax = ax3, color ='g')
ax4.set_title('After Min-Max Scaling')

sns.kdeplot(minmaxdf['mean_gmrt1'], ax = ax4, color ='black')
sns.kdeplot(minmaxdf['mean_jerk_in_air1'], ax = ax4, color ='g')
plt.show()
plt.savefig('n5.jpeg')

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols = 4, figsize =(20, 5))
ax1.set_title('Before Scaling')

sns.kdeplot(X_df['mean_gmrt25'], ax = ax1, color ='r')
sns.kdeplot(X_df['mean_jerk_in_air25'], ax = ax1, color ='b')
ax2.set_title('After Robust Scaling')


sns.kdeplot(robustdf['mean_gmrt25'], ax = ax2, color ='red')
sns.kdeplot(robustdf['mean_jerk_in_air25'], ax = ax2, color ='blue')
ax3.set_title('After Standard Scaling')

sns.kdeplot(standarddf['mean_gmrt25'], ax = ax3, color ='black')
sns.kdeplot(standarddf['mean_jerk_in_air25'], ax = ax3, color ='g')
ax4.set_title('After Min-Max Scaling')

sns.kdeplot(minmaxdf['mean_gmrt25'], ax = ax4, color ='black')
sns.kdeplot(minmaxdf['mean_jerk_in_air25'], ax = ax4, color ='g')
plt.show()
plt.savefig('n6.jpeg')
