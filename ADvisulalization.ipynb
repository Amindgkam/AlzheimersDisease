# %%
import pandas as pd

data = pd.read_csv('data.csv')
data.head()
# Out:
#      ID  air_time1  disp_index1  ...  pressure_var25  total_time25  class
# 0  id_1       5160     0.000013  ...     296102.7676        144605      P
# 1  id_2      51980     0.000016  ...     278744.2850        298640      P
# 2  id_3       2600     0.000010  ...     144411.7055         79025      P
# 3  id_4       2130     0.000010  ...     230184.7154        181220      P
# 4  id_5       2310     0.000007  ...     158290.0255         72575      P
#
# [5 rows x 452 columns]

# %%
len(data.columns)
# Out:
# 452

# %%
data['class'] = data['class'].map({'P':1, 'H':0})

# %%
data.head()
# Out:
#      ID  air_time1  disp_index1  ...  pressure_var25  total_time25  class
# 0  id_1       5160     0.000013  ...     296102.7676        144605      1
# 1  id_2      51980     0.000016  ...     278744.2850        298640      1
# 2  id_3       2600     0.000010  ...     144411.7055         79025      1
# 3  id_4       2130     0.000010  ...     230184.7154        181220      1
# 4  id_5       2310     0.000007  ...     158290.0255         72575      1
#
# [5 rows x 452 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = data.columns[-8:]
plt.figure(figsize=(20, 10))
sns.pairplot(data=data[features], hue='class', markers=['o', 's'])

plt.show()
